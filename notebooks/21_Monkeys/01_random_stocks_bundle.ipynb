# %%
# %load_ext nb_black

# %%
import requests
import zipfile

# %% [markdown]
# Download the dataset from Anreas Clenow's [website](https://www.followingthetrend.com/trading-evolved/):

# %%
DATA_FOLDER = "/tmp"

# %%
data_url = "https://dl.dropbox.com/s/etocgt9zgeedo22/data.zip?dl=1"

# %%
r = requests.get(data_url)
assert r.ok

# %%
# %%bash
# cd /tmp
# rm -rf random_test_data
# rm -f random_test_data.zip

# %%
with open(f"{DATA_FOLDER}/random_test_data.zip", "wb") as f:
    f.write(r.content)

with zipfile.ZipFile(f"{DATA_FOLDER}/random_test_data.zip", "r") as zip_ref:
    zip_ref.extractall(f"{DATA_FOLDER}/random_test_data")

# %% [markdown]
# Script to register the random stock bundle:

# %%
# %%writefile ~/.zipline/random_stock_data.py

import pandas as pd
from os import listdir

# Change the path to where you have your data
path = "/tmp/random_test_data/data/random_stocks"



"""
The ingest function needs to have this exact signature,
meaning these arguments passed, as shown below.
"""
def random_stock_data(environ,
                  asset_db_writer,
                  minute_bar_writer,
                  daily_bar_writer,
                  adjustment_writer,
                  calendar,
                  start_session,
                  end_session,
                  cache,
                  show_progress,
                  output_dir):
    
    # Get list of files from path
    # Slicing off the last part
    # 'example.csv'[:-4] = 'example'
    symbols = [f[:-4] for f in listdir(path)]
    
    if not symbols:
        raise ValueError("No symbols found in folder.")
        
        
    # Prepare an empty DataFrame for dividends
    divs = pd.DataFrame(columns=['sid', 
                                 'amount',
                                 'ex_date', 
                                 'record_date',
                                 'declared_date', 
                                 'pay_date']
    )
    
    # Prepare an empty DataFrame for splits
    splits = pd.DataFrame(columns=['sid',
                                   'ratio',
                                   'effective_date']
    )
    
    # Prepare an empty DataFrame for metadata
    metadata = pd.DataFrame(columns=('start_date',
                                              'end_date',
                                              'auto_close_date',
                                              'symbol',
                                              'exchange'
                                              )
                                     )


    # Check valid trading dates, according to the selected exchange calendar
    sessions = calendar.sessions_in_range(start_session, end_session)
    
    # Get data for all stocks and write to Zipline
    daily_bar_writer.write(
            process_stocks(symbols, sessions, metadata, divs)
            )

    # Write the metadata
    asset_db_writer.write(equities=metadata)
    
    # Write splits and dividends
    adjustment_writer.write(splits=splits,
                            dividends=divs)    
    
    
"""
Generator function to iterate stocks,
build historical data, metadata 
and dividend data
"""
def process_stocks(symbols, sessions, metadata, divs):
    # Loop the stocks, setting a unique Security ID (SID)
    for sid, symbol in enumerate(symbols):
        
        print('Loading {}...'.format(symbol))
        # Read the stock data from csv file.
        df = pd.read_csv('{}/{}.csv'.format(path, symbol), index_col=[0], parse_dates=[0]) 
        
        # Check first and last date.
        start_date = df.index[0]
        end_date = df.index[-1]        
        
        # Synch to the official exchange calendar
        df = df.reindex(sessions.tz_localize(None))[start_date:end_date]
        
        # Forward fill missing data
        df.fillna(method='ffill', inplace=True)
        
        # Drop remaining NaN
        df.dropna(inplace=True)    
        
        # The auto_close date is the day after the last trade.
        ac_date = end_date + pd.Timedelta(days=1)
        
        # Add a row to the metadata DataFrame. Don't forget to add an exchange field.
        metadata.loc[sid] = start_date, end_date, ac_date, symbol, "NYSE"
        
        # If there's dividend data, add that to the dividend DataFrame
        if 'dividend' in df.columns:
            
            # Slice off the days with dividends
            tmp = df[df['dividend'] != 0.0]['dividend']
            div = pd.DataFrame(data=tmp.index.tolist(), columns=['ex_date'])
            
            # Provide empty columns as we don't have this data for now
            div['record_date'] = pd.NaT
            div['declared_date'] = pd.NaT
            div['pay_date'] = pd.NaT            
            
            # Store the dividends and set the Security ID
            div['amount'] = tmp.tolist()
            div['sid'] = sid
            
            # Start numbering at where we left off last time
            ind = pd.Index(range(divs.shape[0], divs.shape[0] + div.shape[0]))
            div.set_index(ind, inplace=True)
            
            # Append this stock's dividends to the list of all dividends
            divs = divs.append(div)    
            
        yield sid, df
# Out:
# Overwriting /root/.zipline/random_stock_data.py

# %% [markdown]
# Update `extension.py` to be able to register this bundle:

# %%
# %%writefile -a ~/.zipline/extension.py


from zipline.data.bundles import register

import random_stock_data
register('random_stocks', random_stock_data.random_stock_data, calendar_name='NYSE')
# Out:
# Appending to /root/.zipline/extension.py

# %% [markdown]
# Ingest the bundle:

# %%
# %%bash
#
# PYTHONPATH="$HOME/.zipline" zipline ingest -b 'random_stocks'
# Out:
# Loading AMD...
# Loading BAC-199809...
# Loading SPLS-201709...
# Loading BBT...
# Loading DWDP...
# Loading WFM-201708...
# Loading AON...
# Loading ICE...
# Loading XOM...
# Loading HES...
# Loading XL...
# Loading RRD...
# Loading COV-201501...
# Loading HBI...
# Loading CCE...
# Loading GDW-200609...
# Loading JOS-200005...
# Loading IPG...
# Loading CNX...
# Loading AABA...
# Loading AMG...
# Loading UH-200005...
# Loading XLNX...
# Loading ASND-199906...
# Loading EXPE...
# Loading SEE...
# Loading SWKS...
# Loading KATE-201707...
# Loading ATI-199906...
# Loading COF...
# Loading DIGI-199809...
# Loading MTL-199909...
# Loading SYF...
# Loading TA-199907...
# Loading CBH-200803...
# Loading DG...
# Loading FISV...
# Loading AKAM...
# Loading HMA-201401...
# Loading BAX...
# Loading KSE-200708...
# Loading EA...
# Loading IP...
# Loading TJX...
# Loading BJS-201004...
# Loading BHMSQ-200401...
# Loading IDXX...
# Loading HCA-200611...
# Loading SHW...
# Loading BF.B...
# Loading XEC...
# Loading SIAL-201511...
# Loading PX...
# Loading MSFT...
# Loading CPRT...
# Loading CELG...
# Loading ARNC...
# Loading NYN-199708...
# Loading FTI-201701...
# Loading VTR...
# Loading BVSN...
# Loading CNW-201510...
# Loading CCI-199810...
# Loading C-199811...
# Loading PNU-200003...
# Loading ROH-200904...
# Loading ACAS-201701...
# Loading HII...
# Loading GCO...
# Loading OK-200104...
# Loading MERQ-200611...
# Loading HNZ-201306...
# Loading DALRQ-200704...
# Loading CLF...
# Loading DOV...
# Loading ETR...
# Loading MRN-199606...
# Loading KEYS...
# Loading BIG...
# Loading NWSA...
# Loading JEF...
# Loading MMM...
# Loading PRGO...
# Loading SK-199805...
# Loading HPQ...
# Loading KRFT-201507...
# Loading AVB...
# Loading SII-201008...
# Loading C...
# Loading NKTR...
# Loading ESRX-201812...
# Loading HM-200112...
# Loading FWLT-201412...
# Loading TROW...
# Loading ABX...
# Loading GX-200201...
# Loading COTY...
# Loading SMS-200007...
# Loading ECO-200301...
# Loading INGR-200611...
# Loading CVG...
# Loading DFS...
# Loading MYL...
# Loading GIDL-199709...
# Loading KIM...
# Loading JOY-201704...
# Loading OAT-200108...
# Loading USBC-199708...
# Loading HET-200801...
# Loading MDR...
# Loading LO-201506...
# Loading MO...
# Loading ADT-201604...
# Loading VAR...
# Loading AEP...
# Loading CITGQ-200912...
# Loading CVC-201606...
# Loading BA...
# Loading ASN-200710...
# Loading CDNS...
# Loading CTX-200908...
# Loading TER...
# Loading DG-200707...
# Loading BDK-201003...
# Loading SE-201702...
# Loading FLR...
# Loading CCK...
# Loading PPW-199911...
# Loading RDC...
# Loading MTG...
# Loading SLR-200710...
# Loading WU...
# Loading AS-199909...
# Loading JWN...
# Loading CIEN...
# Loading AMT...
# Loading ADM...
# Loading AOS...
# Loading I-199603...
# Loading WY...
# Loading JP-200603...
# Loading LEHMQ-201203...
# Loading FCN-199810...
# Loading SNV...
# Loading MAS...
# Loading VLO...
# Loading IRM...
# Loading PHM...
# Loading PSFT-200501...
# Loading PCP-201601...
# Loading KG-201102...
# Loading COV-200203...
# Loading K...
# Loading EQIX...
# Loading SCI...
# Loading A...
# Loading HTMXQ-200907...
# Loading HBOC-199901...
# Loading USB...
# Loading BXLT-201606...
# Loading CAL...
# Loading AIV...
# Loading CBB-199801...
# Loading AEE...
# Loading NSC...
# Loading AZO...
# Loading IKN-200810...
# Loading PEP...
# Loading NWS...
# Loading APC...
# Loading BC...
# Loading CI...
# Loading ECL...
# Loading CHTR...
# Loading RX-201002...
# Loading INTC...
# Loading DNB...
# Loading VNO...
# Loading POM-201603...
# Loading CHIR-200604...
# Loading FLMIQ-200408...
# Loading ARG-201605...
# Loading LSI-201405...
# Loading GRN-199812...
# Loading ADBE...
# Loading CMCSK-201512...
# Loading DXC...
# Loading RAI-201707...
# Loading CL...
# Loading LRCX...
# Loading TWTR...
# Loading FRM-199612...
# Loading SEBL-200601...
# Loading MAC...
# Loading SBUX...
# Loading XEL...
# Loading HAS...
# Loading IAC...
# Loading SCHW...
# Loading ZBH...
# Loading WAMUQ-201203...
# Loading HSH-201408...
# Loading AMAT...
# Loading JBHT...
# Loading CGP-200101...
# Loading NLSN...
# Loading AW-200812...
# Loading SXCL-201702...
# Loading FFIV...
# Loading NUE...
# Loading AYE-201102...
# Loading ED...
# Loading DI-199809...
# Loading GPS...
# Loading AYI...
# Loading AM-201308...
# Loading MNST...
# Loading MET...
# Loading BEV-200603...
# Loading FTL.A-200004...
# Loading ZION...
# Loading RAL-200112...
# Loading LLTC-201703...
# Loading WPX...
# Loading WYNN...
# Loading ACS-201002...
# Loading KBH...
# Loading FRT...
# Loading HFC...
# Loading JEC...
# Loading MEDI-200706...
# Loading EOG...
# Loading FTR...
# Loading TPR...
# Loading GM...
# Loading MAA...
# Loading SNT-199910...
# Loading T...
# Loading KSU...
# Loading APOL-201702...
# Loading SPG...
# Loading PDCO...
# Loading PCH...
# Loading GP-200512...
# Loading TXU-200710...
# Loading SANM...
# Loading APD...
# Loading RTN...
# Loading FOXA...
# Loading WYE-200910...
# Loading COP...
# Loading EC-200606...
# Loading TIE-201301...
# Loading TDM-199708...
# Loading ACKH-200211...
# Loading PLD-201106...
# Loading CMX-200703...
# Loading GNW...
# Loading LU-200611...
# Loading EQT...
# Loading Q-201103...
# Loading HOLX...
# Loading NMK-200201...
# Loading NEU...
# Loading GME...
# Loading GENZ-201104...
# Loading PVN-200509...
# Loading UCM-200010...
# Loading CHA-200006...
# Loading HUM...
# Loading KMI-200705...
# Loading FLS...
# Loading RF...
# Loading NCE-200008...
# Loading PZE-199908...
# Loading SCG...
# Loading PGL-200702...
# Loading MFE-201102...
# Loading GLW...
# Loading DGX...
# Loading APCC-200702...
# Loading DHI...
# Loading DF...
# Loading BCR-201712...
# Loading LEG...
# Loading SK-200006...
# Loading WIN...
# Loading KRB-200512...
# Loading JCI...
# Loading ANDV-201809...
# Loading CLX...
# Loading CPNLQ-200802...
# Loading RHT...
# Loading CPB...
# Loading PGR...
# Loading LOW...
# Loading PETM-201503...
# Loading BFI-199907...
# Loading VRSN...
# Loading PTC...
# Loading EVRG...
# Loading SYK...
# Loading KO...
# Loading GR-201207...
# Loading GLD-199705...
# Loading CCU-200807...
# Loading NYX-201311...
# Loading ITW...
# Loading HCR-200712...
# Loading GOOG...
# Loading AIT-199910...
# Loading VFC...
# Loading VIAB...
# Loading CFC-200806...
# Loading SOV-200901...
# Loading NCR...
# Loading SB-199711...
# Loading NAV...
# Loading TEL...
# Loading UST-200901...
# Loading JAVA-201001...
# Loading BLL...
# Loading TX-200110...
# Loading UVN-200703...
# Loading CCTYQ-201009...
# Loading MWW-201610...
# Loading TLAB-201312...
# Loading WMB...
# Loading FDX...
# Loading MU...
# Loading ZRN-199806...
# Loading GE...
# Loading JCP...
# Loading FLTWQ-200907...
# Loading V...
# Loading PDG-200603...
# Loading CTAS...
# Loading FL...
# Loading WWY-200810...
# Loading BUD-200811...
# Loading MAT...
# Loading FLT...
# Loading TMUS...
# Loading CHRW...
# Loading PGN-201207...
# Loading MGM...
# Loading DRE...
# Loading MSCI...
# Loading ROK...
# Loading NOC...
# Loading QCOM...
# Loading PXD...
# Loading SUNEQ-201712...
# Loading EMN...
# Loading PPL...
# Loading NOVL-201104...
# Loading MPC...
# Loading INTU...
# Loading CA-201811...
# Loading HAR-201703...
# Loading BIIB...
# Loading T-200511...
# Loading PEL-199706...
# Loading EL...
# Loading PRU...
# Loading TMK...
# Loading DVA...
# Loading AR-199911...
# Loading NSM-201109...
# Loading BTUUQ-201704...
# Loading DLR...
# Loading HCP...
# Loading CVH-201305...
# Loading UA...
# Loading PEG...
# Loading DAL...
# Loading TDC...
# Loading PD-200703...
# Loading BDX...
# Loading TAP...
# Loading MII-199906...
# Loading MEL-200706...
# Loading NRG...
# Loading THC...
# Loading OKE...
# Loading STX...
# Loading DVN...
# Loading MS...
# Loading ANDV...
# Loading KRI-200606...
# Loading ABT...
# Loading ZE-199805...
# Loading MTW...
# Loading ALK...
# Loading CSCO...
# Loading GFS.A-199810...
# Loading CSE-199911...
# Loading GRA-199609...
# Loading PALM-201006...
# Loading HI-200303...
# Loading ESRX...
# Loading GIS...
# Loading TRV...
# Loading DPHIQ-200910...
# Loading NVLS-201206...
# Loading AMP-199904...
# Loading STJ-201701...
# Loading NI...
# Loading KR...
# Loading JPM...
# Loading SWY-201501...
# Loading CR...
# Loading PLL-201508...
# Loading GTE-200006...
# Loading TSCO...
# Loading MDP...
# Loading ORCL...
# Loading DDR...
# Loading RYI-200710...
# Loading LNT...
# Loading VRTS-200507...
# Loading AVP...
# Loading R...
# Loading UNP...
# Loading JNJ...
# Loading IFF...
# Loading NFX...
# Loading CINF...
# Loading ESV...
# Loading RHI...
# Loading TRB-200712...
# Loading FSLR...
# Loading SNDK-201605...
# Loading CPGX-201606...
# Loading STR-201609...
# Loading PBI...
# Loading VAT-199609...
# Loading DLX...
# Loading CTSH...
# Loading UCC-199904...
# Loading SIVB...
# Loading CHRS-201206...
# Loading COL-201811...
# Loading NEM...
# Loading SVU...
# Loading INFO...
# Loading ALB...
# Loading CAH...
# Loading SFA-200602...
# Loading HRS...
# Loading S-200503...
# Loading BFO-200010...
# Loading WFT...
# Loading STT...
# Loading CDD-200005...
# Loading AVY...
# Loading NFLX...
# Loading DCNAQ-200801...
# Loading USG...
# Loading DD-201708...
# Loading CYR-199606...
# Loading DDS...
# Loading FDO-201507...
# Loading AV-200710...
# Loading BSX...
# Loading EQ-200906...
# Loading XL-201809...
# Loading CEG-201203...
# Loading M...
# Loading WEC...
# Loading ATGE...
# Loading ADCT-201012...
# Loading ES...
# Loading JKHY...
# Loading JNS-201705...
# Loading HLT-200710...
# Loading BGEN-200311...
# Loading TXT...
# Loading PNR...
# Loading KHC...
# Loading IQV...
# Loading PBG-201002...
# Loading KDP...
# Loading BMY...
# Loading CPQ-200205...
# Loading VRTX...
# Loading CXO...
# Loading WB-200108...
# Loading CA...
# Loading NEC-199706...
# Loading HCBK-201510...
# Loading PCAR...
# Loading ESS...
# Loading SNPS...
# Loading MCK...
# Loading ECH-199807...
# Loading LMT...
# Loading SWN...
# Loading FCX...
# Loading H-200704...
# Loading PYPL...
# Loading TOS-200109...
# Loading CBS...
# Loading HST...
# Loading WNDXQ-200611...
# Loading EQR...
# Loading OWENQ-200610...
# Loading EFU-200011...
# Loading ASC-199906...
# Loading TEG-201506...
# Loading BT-199906...
# Loading TEX...
# Loading FIS...
# Loading FNMA...
# Loading FCPT...
# Loading IPGP...
# Loading JCI-201609...
# Loading HRB...
# Loading NCLH...
# Loading WFC-199811...
# Loading JPM-200012...
# Loading SUB-200102...
# Loading FRX-201406...
# Loading AKS...
# Loading SSP...
# Loading GWF-199707...
# Loading BNI-201002...
# Loading AN-199812...
# Loading FSH-200611...
# Loading HDLM-201301...
# Loading PSA...
# Loading WCG...
# Loading GGP...
# Loading DLTR...
# Loading IVZ...
# Loading SEG-200011...
# Loading GOSHA-200507...
# Loading HSY...
# Loading HOG...
# Loading BHGE...
# Loading NTRS...
# Loading KWP-199911...
# Loading OM-199709...
# Loading FITB...
# Loading CHK...
# Loading EOP-200702...
# Loading BBY...
# Loading AET-201811...
# Loading ATI...
# Loading SLG...
# Loading SHN-200007...
# Loading TRW-200212...
# Loading CMG...
# Loading WCOEQ-200404...
# Loading SUN-201210...
# Loading DHR...
# Loading CNG-200001...
# Loading JNY-201404...
# Loading CBOE...
# Loading PLD...
# Loading SNA...
# Loading WOR...
# Loading CSX...
# Loading PAYX...
# Loading HPE...
# Loading TOY-200507...
# Loading ASO-200611...
# Loading GNT-199806...
# Loading GT...
# Loading MTLQQ-201103...
# Loading HON-199912...
# Loading THY-199708...
# Loading LPX...
# Loading UNH...
# Loading CRM...
# Loading FBHS...
# Loading OMC...
# Loading UHS...
# Loading GRMN...
# Loading PMCS-201601...
# Loading AMZN...
# Loading L...
# Loading CF...
# Loading FMY-199905...
# Loading WEN-200809...
# Loading PMI-199911...
# Loading AXP...
# Loading SMI-200109...
# Loading JBL...
# Loading AMH-199709...
# Loading UAA...
# Loading MOB-199911...
# Loading CHD...
# Loading UIS...
# Loading UAL...
# Loading ITT...
# Loading MA...
# Loading FII...
# Loading SRR-200708...
# Loading BWA...
# Loading RRC...
# Loading MMI-201205...
# Loading BRCM-201601...
# Loading NLV-200001...
# Loading USHC-199607...
# Loading MER-200812...
# Loading TGT...
# Loading AWK...
# Loading WYND...
# Loading PWER-201307...
# Loading TSS...
# Loading LXK-201611...
# Loading WAI-199808...
# Loading CE...
# Loading VIAV...
# Loading UPR-200007...
# Loading BR-200603...
# Loading COC.B-200208...
# Loading CEPH-201110...
# Loading HFS-199712...
# Loading USH-199706...
# Loading FRC...
# Loading MWV-201507...
# Loading CNP...
# Loading MDT...
# Loading AT-200711...
# Loading LB...
# Loading PCS-200404...
# Loading RBD-199903...
# Loading PVT-199906...
# Loading ADS...
# Loading MEE-201106...
# Loading ALTR-201512...
# Loading SIG...
# Loading APTV...
# Loading ADSK...
# Loading NSI-200306...
# Loading YUM...
# Loading BMGCA-200101...
# Loading BEN...
# Loading LLY...
# Loading ORLY...
# Loading ANRZQ-201607...
# Loading RATL-200302...
# Loading DGN-199910...
# Loading LUB...
# Loading LIFE-201402...
# Loading FBF-200403...
# Loading USS-199810...
# Loading UPC-200406...
# Loading MNR-199809...
# Loading AES...
# Loading PAC-199703...
# Loading NAE-199708...
# Loading RNB-199912...
# Loading LKQ...
# Loading MOLX-201312...
# Loading BRL-200812...
# Loading CEN-200711...
# Loading MRK...
# Loading JH-200705...
# Loading FSL-200612...
# Loading SGP-200911...
# Loading DUK...
# Loading DOW-201708...
# Loading DTE...
# Loading LYB...
# Loading NKE...
# Loading UCL-200508...
# Loading RDS.A...
# Loading HPH-199912...
# Loading PM...
# Loading MUR...
# Loading AMP...
# Loading WB-200812...
# Loading HCA...
# Loading HBAN...
# Loading CPRI...
# Loading ALLE...
# Loading CMCSA...
# Loading NLC-199912...
# Loading CNC...
# Loading ADI...
# Loading REGN...
# Loading NGH-200012...
# Loading UNM...
# Loading CPWR-201412...
# Loading TTWO...
# Loading NAVI...
# Loading PRD-200110...
# Loading EXR...
# Loading RL...
# Loading EDS-200808...
# Loading PFE...
# Loading KEY...
# Loading MHS-201203...
# Loading WLP-200411...
# Loading TMC.A-200006...
# Loading TIF...
# Loading MD-199707...
# Loading SYMC...
# Loading CCEP...
# Loading RYAN-200610...
# Loading INCY...
# Loading AET...
# Loading CME...
# Loading AZA.A-200106...
# Loading BCO...
# Loading TXN...
# Loading CIT.A-200106...
# Loading SFS-200008...
# Loading TT-200806...
# Loading PX-201810...
# Loading BGG...
# Loading ZTS...
# Loading SOTR-200410...
# Loading SDS-200508...
# Loading X...
# Loading GS...
# Loading JNPR...
# Loading LDOS...
# Loading SAPE-201502...
# Loading MMC...
# Loading F...
# Loading BMET-200709...
# Loading EMR...
# Loading MDLZ...
# Loading MBI...
# Loading COL...
# Loading RCL...
# Loading MKG-200010...
# Loading PH...
# Loading OMX-201311...
# Loading HIG...
# Loading MEA-200201...
# Loading H-200107...
# Loading BKNG...
# Loading SRCL...
# Loading XTO-201006...
# Loading QTRN-200309...
# Loading RJF...
# Loading QRVO...
# Loading WLA-200006...
# Loading AGN-201503...
# Loading COG...
# Loading S...
# Loading CMI...
# Loading USW-200006...
# Loading HPC-200811...
# Loading SCG-201812...
# Loading EW...
# Loading BAC...
# Loading WMX-199807...
# Loading CVS...
# Loading RMD...
# Loading MTD...
# Loading QEP...
# Loading PHB-199910...
# Loading ABC...
# Loading FMC...
# Loading MYG-200603...
# Loading ABI-200811...
# Loading UTX...
# Loading AAPL...
# Loading PKI...
# Loading NFB-200611...
# Loading GPU-200111...
# Loading BBBY...
# Loading CBRE...
# Loading ANET...
# Loading CF-200408...
# Loading TSN...
# Loading BOAT-199701...
# Loading BMS...
# Loading LUV...
# Loading YNR-200010...
# Loading VZ...
# Loading EXPD...
# Loading FRO-199909...
# Loading AMCC-201701...
# Loading MIR-201012...
# Loading TMO...
# Loading HSP-201509...
# Loading GDT-200604...
# Loading HOT-201609...
# Loading LLX-199710...
# Loading BLS-200612...
# Loading ROL...
# Loading GLK-200507...
# Loading WLL-200203...
# Loading IGT-201504...
# Loading PWR...
# Loading ABKFQ-201304...
# Loading ANTM...
# Loading CAT...
# Loading BSET...
# Loading SKY...
# Loading CE-200402...
# Loading DELL-201310...
# Loading GHC...
# Loading GRA-199803...
# Loading AFS.A-200011...
# Loading EFX...
# Loading O...
# Loading FOX...
# Loading BEAM-201404...
# Loading PFG...
# Loading HD...
# Loading DNR...
# Loading AWE-200410...
# Loading CNXT-201104...
# Loading CSR-200006...
# Loading DYN-201804...
# Loading EVHC-201810...
# Loading MWI-200402...
# Loading FB...
# Loading TEK-200711...
# Loading CFG...
# Loading ENS-199708...
# Loading FOSL...
# Loading AMGN...
# Loading PWJ-200011...
# Loading GGP-201808...
# Loading PVH...
# Loading MXIM...
# Loading PKG...
# Loading ALL...
# Loading ODP...
# Loading CFL-199804...
# Loading TRIP...
# Loading TE-201606...
# Loading ENRNQ-200411...
# Loading CMB-199603...
# Loading NXTL-200508...
# Loading NWL...
# Loading LH...
# Loading FBO-199603...
# Loading BR...
# Loading LLL...
# Loading PSX...
# Loading DJ-200712...
# Loading MZIAQ-201010...
# Loading BAY-199808...
# Loading MSI...
# Loading TWC-201605...
# Loading ROP...
# Loading OI...
# Loading CBE-201211...
# Loading RYC-199908...
# Loading LDW.B-200012...
# Loading TNB-201205...
# Loading AIZ...
# Loading WAT...
# Loading ATVI...
# Loading LOR-199604...
# Loading SYY...
# Loading WLTW...
# Loading ETS-200603...
# Loading IT...
# Loading NYT...
# Loading WBA...
# Loading EVHC...
# Loading CG-200011...
# Loading AAP...
# Loading BSC-200805...
# Loading NE...
# Loading UPS...
# Loading AME...
# Loading ENDP...
# Loading GILD...
# Loading LDG-200810...
# Loading WFC...
# Loading BXP...
# Loading CB-201601...
# Loading WRK...
# Loading CBSS-200709...
# Loading BLK...
# Loading RIG...
# Loading BK...
# Loading MJN-201706...
# Loading FLIR...
# Loading NRTLQ-201510...
# Loading VSTNQ-201010...
# Loading ETN...
# Loading ADP...
# Loading ASH...
# Loading SAI-199812...
# Loading WM...
# Loading MLM...
# Loading AN...
# Loading NEE...
# Loading FAST...
# Loading RLM-200005...
# Loading DISCA...
# Loading AIG...
# Loading CYM-199912...
# Loading COMS-201004...
# Loading URBN...
# Loading LIT-200105...
# Loading CMA...
# Loading AAMRQ-201312...
# Loading APH...
# Loading ORX-199902...
# Loading ANDW-200712...
# Loading GPN...
# Loading CIN-200603...
# Loading G-200509...
# Loading SPGI...
# Loading RSHCQ-201510...
# Loading EHC...
# Loading KM-200212...
# Loading CVX...
# Loading UN...
# Loading ULTA...
# Loading OXY...
# Loading IBM...
# Loading GSX-199810...
# Loading JHF-200404...
# Loading SO...
# Loading ILMN...
# Loading CERN...
# Loading LNC...
# Loading DWD-199705...
# Loading CMVT-201302...
# Loading CSRA-201804...
# Loading ANV-199904...
# Loading XRX...
# Loading RSG...
# Loading MCD...
# Loading XRAY...
# Loading ETFC...
# Loading TGNA...
# Loading KLAC...
# Loading CNC-200208...
# Loading QLGC-201608...
# Loading VO-200012...
# Loading TMC-200006...
# Loading CTXS...
# Loading BNL-199806...
# Loading FDC-200709...
# Loading STI...
# Loading REG...
# Loading SWK...
# Loading DTV-201507...
# Loading CAG...
# Loading UAWGQ-200303...
# Loading GPC...
# Loading FPC-200011...
# Loading SRE...
# Loading TUP...
# Loading APA...
# Loading INCLF-200701...
# Loading SBL-200701...
# Loading PBY-201602...
# Loading ISRG...
# Loading UDR...
# Loading CTB...
# Loading BBI-199801...
# Loading AJG...
# Loading EBAY...
# Loading MST-199808...
# Loading SHLD...
# Loading CCB-199602...
# Loading FTI...
# Loading SBAC...
# Loading GAPTQ-201203...
# Loading PNW...
# Loading MAY-200508...
# Loading UK-200102...
# Loading WELL...
# Loading KSS...
# Loading SAF-200809...
# Loading EP-201205...
# Loading AGN...
# Loading LEN...
# Loading GMCR-201603...
# Loading YRCW...
# Loading ALGN...
# Loading FJ-200011...
# Loading LM...
# Loading PCL-201602...
# Loading MAR...
# Loading CAM-201604...
# Loading ABBV...
# Loading DEC-199806...
# Loading HP...
# Loading SGID-200610...
# Loading FHN...
# Loading HRL...
# Loading WDC...
# Loading KMX...
# Loading ABS-200606...
# Loading USB-200102...
# Loading VRSK...
# Loading CCL...
# Loading HON...
# Loading PET-199806...
# Loading IR...
# Loading TSG-200703...
# Loading NCC-200812...
# Loading AHM-199810...
# Loading BOL-200710...
# Loading MCO...
# Loading DIS...
# Loading ACN...
# Loading PPG...
# Loading NC...
# Loading WHR...
# Loading MCHP...
# Loading DRI...
# Loading BRK.B...
# Loading CMS...
# Loading MOS...
# Loading FE...
# Loading VTSS-201504...
# Loading COO...
# Loading AL-200711...
# Loading TEN...
# Loading CCI...
# Loading FANG...
# Loading SLM...
# Loading AGC-200108...
# Loading RE...
# Loading GRA...
# Loading FTV...
# Loading KORS...
# Loading NOV...
# Loading RAD...
# Loading MIR-200005...
# Loading BKB-199909...
# Loading EMC-201609...
# Loading VMC...
# Loading GWW...
# Loading EXC...
# Loading MIL-201007...
# Loading NTAP...
# Loading NBR...
# Loading STO-199811...
# Loading FTNT...
# Loading DISH...
# Loading PG...
# Loading ACV-201105...
# Loading BMC-201309...
# Loading PBCT...
# Loading HLT...
# Loading GTW-200710...
# Loading XYL...
# Loading VVI...
# Loading HSIC...
# Loading URI...
# Loading HAL...
# Loading MHK...
# Loading ONE-200406...
# Loading ANF...
# Loading ABMD...
# Loading GOOGL...
# Loading EKDKQ-201309...
# Loading TWX-200101...
# Loading LVLT-201710...
# Loading SVU-201810...
# Loading ARC-200004...
# Loading FMCC...
# Loading AFL...
# Loading CRR-199706...
# Loading GAS-201606...
# Loading ARE...
# Loading MI-201107...
# Loading STZ...
# Loading KMB...
# Loading NBL...
# Loading DE...
# Loading COST...
# Loading CAR...
# Loading BLY-199612...
# Loading AAL...
# Loading PNC...
# Loading TWX-201806...
# Loading AAL-199702...
# Loading MRO...
# Loading SNI-201803...
# Loading UMG-200006...
# Loading CFN-201503...
# Loading SLB...
# Loading NDAQ...
# Loading LW...
# Loading RBK-200601...
# Loading SPXC...
# Loading RML-200608...
# Loading CBS-200005...
# Loading ANSS...
# Loading CB...
# Loading TCOMA-199903...
# Loading CTL...
# Loading DO...
# Loading TKR...
# Loading GD...
# Loading ROST...
# Loading AVGO...
# Loading KMI...
# Loading DISCK...
# Loading MTB...
# Loading PCG...
# Loading PTV-201011...
# Loading PVN-199706...
# Loading SJM...
# Loading ALXN...
# Loading MKC...
# Loading BHF...
# Loading MON-201806...
# Loading MCIC-199809...
# Loading PAS-201002...
# Loading WMT...
# Loading TDG...
# Loading IMNX-200207...
# Loading FG-199804...
# Loading GAS-201112...
# Loading D...
# Loading TIN-201202...
# Loading KMG-200608...
# Loading ITT-199802...
# Loading FJCC-200809...
# Loading PHA-200304...
# Loading EIX...
# Loading MNK...
# Loading NVDA...
# [2020-11-21 04:00:43.183668] INFO: zipline.data.bundles.core: Ingesting random_stocks.

# %% [markdown]
# Check bundle exists:

# %%
# %%bash
#
# zipline bundles
# Out:
# csvdir <no ingestions>
# quandl 2020-11-21 03:15:00.901882
# quandl 2020-11-21 02:49:44.034626
# quandl 2020-11-20 10:22:51.269033
# quandl 2020-11-15 16:10:56.034164
# quandl 2020-11-15 16:10:22.008242
# quandl 2020-11-15 16:07:52.722994
# quantopian-quandl <no ingestions>
# random_futures 2020-11-20 13:49:05.277535
# random_futures 2020-11-20 11:03:32.137763
# random_futures 2020-11-15 16:12:43.061226
# random_stocks 2020-11-21 04:00:41.273756
# random_stocks 2020-11-21 02:13:14.005937
