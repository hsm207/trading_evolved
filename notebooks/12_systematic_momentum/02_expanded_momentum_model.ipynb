# %%
# %load_ext nb_black

# %%
import zipline
from zipline.api import (
    order_target_percent,
    symbol,
    set_commission,
    set_slippage,
    schedule_function,
    date_rules,
    time_rules,
)
from datetime import datetime
import matplotlib.pyplot as plt
import pyfolio as pf
import pandas as pd
import numpy as np
from scipy import stats
from zipline.finance.commission import PerDollar
from zipline.finance.slippage import VolumeShareSlippage, FixedSlippage

# %%
# Since we don't have real data on the components that make up the S&P 500...

from utils import generate_dummy_sp500_components

INDEX_DATA_PATH = "../../data/sp500.csv"
generate_dummy_sp500_components("1997-01-01", "2018-12-31").to_csv(INDEX_DATA_PATH)

# %%
# Global variables to control backtest

"""
Model Settings
"""
intial_portfolio = 100000
momentum_window1 = 125
momentum_window2 = 125
minimum_momentum = 40
portfolio_size = 30
vola_window = 20

# Trend filter settings
enable_trend_filter = True
trend_filter_symbol = "XOM"
trend_filter_window = 200

"""
Commission and Slippage Settings
"""
enable_commission = True
commission_pct = 0.001
enable_slippage = True
slippage_volume_limit = 0.025
slippage_impact = 0.05

# %%
def momentum_score(ts):
    """
    Input:  Price time series.
    Output: Annualized exponential regression slope,
            multiplied by the R2
    """
    # Note I: The easiest way to calculate exponential regression is to just do
    # a linear regression based on the log values
    #
    # Note II: Idea behind exponential regression: https://rpubs.com/mengxu/exponential-model

    # Make a list of consecutive numbers
    x = np.arange(len(ts))
    # Get logs
    log_ts = np.log(ts)
    # Calculate regression values
    slope, intercept, r_value, p_value, std_err = stats.linregress(x, log_ts)
    # Annualize percent
    annualized_slope = (np.power(np.exp(slope), 252) - 1) * 100
    # Adjust for fitness
    score = annualized_slope * (r_value ** 2)
    return score

# %%
def volatility(ts):
    # vola_window is a global variable!
    return ts.pct_change().rolling(vola_window).std().iloc[-1]

# %%
def output_progress(context):
    """
    Output some performance numbers during backtest run
    This code just prints out the past month's performance
    so that we have something to look at while the backtest runs.
    """

    # Get today's date
    today = zipline.api.get_datetime().date()

    # Calculate percent difference since last month
    perf_pct = (context.portfolio.portfolio_value / context.last_month) - 1

    # Print performance, format as percent with two decimals.
    print("{} - Last Month Result: {:.2%}".format(today, perf_pct))

    # Remember today's portfolio value for next month's calculation
    context.last_month = context.portfolio.portfolio_value

# %%
def initialize(context):

    # Set commission and slippage.
    if enable_commission:
        comm_model = PerDollar(cost=commission_pct)
    else:
        comm_model = PerDollar(cost=0.0)
    set_commission(comm_model)

    if enable_slippage:
        slippage_model = VolumeShareSlippage(
            volume_limit=slippage_volume_limit, price_impact=slippage_impact
        )
    else:
        slippage_model = FixedSlippage(spread=0.0)
    set_slippage(slippage_model)

    # Used only for progress output.
    context.last_month = intial_portfolio

    # Fetch and store index membership
    context.index_members = pd.read_csv(INDEX_DATA_PATH, index_col=0, parse_dates=[0])

    # Schedule rebalance monthly.
    schedule_function(
        func=rebalance,
        date_rule=date_rules.month_start(),
        time_rule=time_rules.market_open(),
    )

# %%
def rebalance(context, data):
    # Write some progress output during the backtest
    output_progress(context)

    # Ok, let's find which stocks can be traded today.

    # First, get today's date
    today = zipline.api.get_datetime()

    # Second, get the index makeup for all days prior to today.
    all_prior = context.index_members.loc[context.index_members.index < today]

    # Now let's snag the first column of the last, i.e. latest, entry.
    latest_day = all_prior.iloc[-1, 0]

    # Split the text string with tickers into a list
    list_of_tickers = latest_day.split(",")

    # Finally, get the Zipline symbols for the tickers
    todays_universe = [symbol(ticker) for ticker in list_of_tickers]

    # There's your daily universe. But we could of course have done this in one go.
    """       
    
    # This line below does the same thing,
    # using the same logic to fetch today's stocks.
    
    todays_universe = [
        symbol(ticker) for ticker in 
        context.index_members.loc[context.index_members.index < today].iloc[-1,0].split(',')
    ]
    """
    # Check how long history window we need.
    hist_window = max(momentum_window1, momentum_window2)

    # Get historical data
    hist = data.history(todays_universe, "close", hist_window, "1d")

    # Slice the history to match the two chosen time frames.
    momentum_hist1 = hist[(-1 * momentum_window1) :]
    momentum_hist2 = hist[(-1 * momentum_window2) :]

    # Calculate momentum values for the two time frames.
    momentum_list1 = momentum_hist1.apply(momentum_score)
    momentum_list2 = momentum_hist2.apply(momentum_score)

    # Now let's put the two momentum values together, and calculate mean.
    momentum_concat = pd.concat((momentum_list1, momentum_list2))
    mom_by_row = momentum_concat.groupby(momentum_concat.index)
    mom_means = mom_by_row.mean()

    # Sort by momentum value.
    ranking_table = mom_means.sort_values(ascending=False)

    """
    Sell Logic
    
    First we check if any existing position should be sold.
    * Sell if stock is no longer part of index.
    * Sell if stock has too low momentum value.
    """
    kept_positions = list(context.portfolio.positions.keys())
    for security in context.portfolio.positions:
        if security not in todays_universe:
            order_target_percent(security, 0.0)
            kept_positions.remove(security)
        elif ranking_table[security] < minimum_momentum:
            order_target_percent(security, 0.0)
            kept_positions.remove(security)

    """
    Trend Filter Section
    """
    if enable_trend_filter:
        ind_hist = data.history(
            symbol(trend_filter_symbol), "close", trend_filter_window, "1d"
        )

        trend_filter = ind_hist.iloc[-1] > ind_hist.mean()
        if trend_filter == False:
            return

    """
    Stock Selection Logic
    
    Check how many stocks we are keeping from last month.
    Fill from top of ranking list, until we reach the
    desired total number of portfolio holdings.
    """
    replacement_stocks = portfolio_size - len(kept_positions)
    buy_list = ranking_table.loc[~ranking_table.index.isin(kept_positions)][
        :replacement_stocks
    ]

    new_portfolio = pd.concat(
        (buy_list, ranking_table.loc[ranking_table.index.isin(kept_positions)])
    )

    """
    Calculate inverse volatility for stocks, 
    and make target position weights.
    """
    vola_table = hist[new_portfolio.index].apply(volatility)
    inv_vola_table = 1 / vola_table
    sum_inv_vola = np.sum(inv_vola_table)
    vola_target_weights = inv_vola_table / sum_inv_vola

    for security, rank in new_portfolio.iteritems():
        weight = vola_target_weights[security]
        if security in kept_positions:
            order_target_percent(security, weight)
        else:
            if ranking_table[security] > minimum_momentum:
                order_target_percent(security, weight)

# %%
def analyze(context, perf):

    perf["max"] = perf.portfolio_value.cummax()
    perf["dd"] = (perf.portfolio_value / perf["max"]) - 1
    maxdd = perf["dd"].min()

    ann_ret = (
        np.power(
            (perf.portfolio_value.iloc[-1] / perf.portfolio_value.iloc[0]),
            (252 / len(perf)),
        )
    ) - 1

    print("Annualized Return: {:.2%} Max Drawdown: {:.2%}".format(ann_ret, maxdd))

    return

# %%
start = pd.Timestamp("1997-01-01 8:15:12", tz="UTC")
end = pd.Timestamp("2017-11-30 8:15:12", tz="UTC")

# %%
# %%time
perf = zipline.run_algorithm(
    start=start,
    end=end,
    initialize=initialize,
    analyze=analyze,
    capital_base=intial_portfolio,
    data_frequency="daily",
    bundle="quandl",  # bundle used in the book was "ac_equities_db"
)
# Out:
# 1997-01-02 - Last Month Result: 0.00%
# 1997-02-03 - Last Month Result: 2.65%
# 1997-03-03 - Last Month Result: 0.85%
# 1997-04-01 - Last Month Result: -2.63%
# 1997-05-01 - Last Month Result: 2.21%
# 1997-06-02 - Last Month Result: 1.51%
# 1997-07-01 - Last Month Result: 1.29%
# 1997-08-01 - Last Month Result: 1.69%
# 1997-09-02 - Last Month Result: -2.01%
# 1997-10-01 - Last Month Result: -0.04%
# 1997-11-03 - Last Month Result: -0.67%
# 1997-12-01 - Last Month Result: -0.51%
# 1998-01-02 - Last Month Result: -0.10%
# 1998-02-02 - Last Month Result: 0.79%
# 1998-03-02 - Last Month Result: -0.02%
# 1998-04-01 - Last Month Result: 0.83%
# 1998-05-01 - Last Month Result: -0.43%
# 1998-06-01 - Last Month Result: -0.56%
# 1998-07-01 - Last Month Result: 3.62%
# 1998-08-03 - Last Month Result: -0.30%
# 1998-09-01 - Last Month Result: -4.85%
# 1998-10-01 - Last Month Result: 0.23%
# 1998-11-02 - Last Month Result: 1.79%
# 1998-12-01 - Last Month Result: -0.09%
# 1999-01-04 - Last Month Result: 0.77%
# 1999-02-01 - Last Month Result: 1.51%
# 1999-03-01 - Last Month Result: -1.01%
# 1999-04-01 - Last Month Result: 0.25%
# 1999-05-03 - Last Month Result: 0.25%
# 1999-06-01 - Last Month Result: -1.85%
# 1999-07-01 - Last Month Result: 1.76%
# 1999-08-02 - Last Month Result: -1.03%
# 1999-09-01 - Last Month Result: 0.70%
# 1999-10-01 - Last Month Result: -0.70%
# 1999-11-01 - Last Month Result: 0.41%
# 1999-12-01 - Last Month Result: 1.69%
# 2000-01-03 - Last Month Result: 2.74%
# 2000-02-01 - Last Month Result: -0.46%
# 2000-03-01 - Last Month Result: 0.50%
# 2000-04-03 - Last Month Result: 0.78%
# 2000-05-01 - Last Month Result: -0.81%
# 2000-06-01 - Last Month Result: -1.85%
# 2000-07-03 - Last Month Result: 1.06%
# 2000-08-01 - Last Month Result: 0.42%
# 2000-09-01 - Last Month Result: -0.06%
# 2000-10-02 - Last Month Result: 1.30%
# 2000-11-01 - Last Month Result: 0.14%
# 2000-12-01 - Last Month Result: -0.14%
# 2001-01-02 - Last Month Result: -0.08%
# 2001-02-01 - Last Month Result: -1.50%
# 2001-03-01 - Last Month Result: -0.20%
# 2001-04-02 - Last Month Result: 0.08%
# 2001-05-01 - Last Month Result: 0.00%
# 2001-06-01 - Last Month Result: 0.00%
# 2001-07-02 - Last Month Result: -0.18%
# 2001-08-01 - Last Month Result: -0.05%
# 2001-09-04 - Last Month Result: -0.19%
# 2001-10-01 - Last Month Result: -0.01%
# 2001-11-01 - Last Month Result: 0.00%
# 2001-12-03 - Last Month Result: 0.00%
# 2002-01-02 - Last Month Result: 0.00%
# 2002-02-01 - Last Month Result: 0.00%
# 2002-03-01 - Last Month Result: 0.00%
# 2002-04-01 - Last Month Result: -0.42%
# 2002-05-01 - Last Month Result: -0.60%
# 2002-06-03 - Last Month Result: -0.84%
# 2002-07-01 - Last Month Result: -0.56%
# 2002-08-01 - Last Month Result: -1.00%
# 2002-09-03 - Last Month Result: -0.05%
# 2002-10-01 - Last Month Result: 0.09%
# 2002-11-01 - Last Month Result: 0.00%
# 2002-12-02 - Last Month Result: 0.00%
# 2003-01-02 - Last Month Result: 0.00%
# 2003-02-03 - Last Month Result: 0.00%
# 2003-03-03 - Last Month Result: 0.00%
# 2003-04-01 - Last Month Result: 0.00%
# 2003-05-01 - Last Month Result: 0.25%
# 2003-06-02 - Last Month Result: 0.08%
# 2003-07-01 - Last Month Result: 0.06%
# 2003-08-01 - Last Month Result: 1.22%
# 2003-09-02 - Last Month Result: 1.18%
# 2003-10-01 - Last Month Result: -0.96%
# 2003-11-03 - Last Month Result: 2.09%
# 2003-12-01 - Last Month Result: 0.40%
# 2004-01-02 - Last Month Result: 0.13%
# 2004-02-02 - Last Month Result: -0.25%
# 2004-03-01 - Last Month Result: 0.65%
# 2004-04-01 - Last Month Result: -0.19%
# 2004-05-03 - Last Month Result: -0.57%
# 2004-06-01 - Last Month Result: 0.17%
# 2004-07-01 - Last Month Result: 0.33%
# 2004-08-02 - Last Month Result: -0.09%
# 2004-09-01 - Last Month Result: 0.19%
# 2004-10-01 - Last Month Result: 0.06%
# 2004-11-01 - Last Month Result: 0.86%
# 2004-12-01 - Last Month Result: 0.57%
# 2005-01-03 - Last Month Result: -0.04%
# 2005-02-01 - Last Month Result: 0.49%
# 2005-03-01 - Last Month Result: 0.93%
# 2005-04-01 - Last Month Result: -0.85%
# 2005-05-02 - Last Month Result: -0.15%
# 2005-06-01 - Last Month Result: -0.10%
# 2005-07-01 - Last Month Result: 0.00%
# 2005-08-01 - Last Month Result: 0.34%
# 2005-09-01 - Last Month Result: -0.31%
# 2005-10-03 - Last Month Result: 0.33%
# 2005-11-01 - Last Month Result: -0.55%
# 2005-12-01 - Last Month Result: 1.26%
# 2006-01-03 - Last Month Result: 0.02%
# 2006-02-01 - Last Month Result: 0.45%
# 2006-03-01 - Last Month Result: -0.12%
# 2006-04-03 - Last Month Result: 0.26%
# 2006-05-01 - Last Month Result: -0.03%
# 2006-06-01 - Last Month Result: -0.36%
# 2006-07-03 - Last Month Result: -0.11%
# 2006-08-01 - Last Month Result: -0.18%
# 2006-09-01 - Last Month Result: 0.01%
# 2006-10-02 - Last Month Result: 0.00%
# 2006-11-01 - Last Month Result: 0.28%
# 2006-12-01 - Last Month Result: -0.01%
# 2007-01-03 - Last Month Result: 0.42%
# 2007-02-01 - Last Month Result: 0.78%
# 2007-03-01 - Last Month Result: -0.64%
# 2007-04-02 - Last Month Result: 0.13%
# 2007-05-01 - Last Month Result: 0.22%
# 2007-06-01 - Last Month Result: 0.03%
# 2007-07-02 - Last Month Result: -0.10%
# 2007-08-01 - Last Month Result: -0.11%
# 2007-09-04 - Last Month Result: 0.45%
# 2007-10-01 - Last Month Result: 0.18%
# 2007-11-01 - Last Month Result: -0.01%
# 2007-12-03 - Last Month Result: -0.53%
# 2008-01-02 - Last Month Result: -0.02%
# 2008-02-01 - Last Month Result: -3.43%
# 2008-03-03 - Last Month Result: 0.22%
# 2008-04-01 - Last Month Result: -0.03%
# 2008-05-01 - Last Month Result: 0.00%
# 2008-06-02 - Last Month Result: -0.03%
# 2008-07-01 - Last Month Result: -0.02%
# 2008-08-01 - Last Month Result: 0.07%
# 2008-09-02 - Last Month Result: 0.06%
# 2008-10-01 - Last Month Result: 0.00%
# 2008-11-03 - Last Month Result: 0.00%
# 2008-12-01 - Last Month Result: 0.00%
# 2009-01-02 - Last Month Result: 0.00%
# 2009-02-02 - Last Month Result: 0.00%
# 2009-03-02 - Last Month Result: 0.00%
# 2009-04-01 - Last Month Result: 0.00%
# 2009-05-01 - Last Month Result: 0.00%
# 2009-06-01 - Last Month Result: 0.00%
# 2009-07-01 - Last Month Result: 0.00%
# 2009-08-03 - Last Month Result: 0.00%
# 2009-09-01 - Last Month Result: 0.00%
# 2009-10-01 - Last Month Result: 0.00%
# 2009-11-02 - Last Month Result: 0.00%
# 2009-12-01 - Last Month Result: 2.76%
# 2010-01-04 - Last Month Result: 1.06%
# 2010-02-01 - Last Month Result: -1.98%
# 2010-03-01 - Last Month Result: 1.05%
# 2010-04-01 - Last Month Result: 0.33%
# 2010-05-03 - Last Month Result: -0.18%
# 2010-06-01 - Last Month Result: -0.05%
# 2010-07-01 - Last Month Result: 0.00%
# 2010-08-02 - Last Month Result: 0.00%
# 2010-09-01 - Last Month Result: 0.00%
# 2010-10-01 - Last Month Result: 0.00%
# 2010-11-01 - Last Month Result: 0.00%
# 2010-12-01 - Last Month Result: 0.82%
# 2011-01-03 - Last Month Result: 1.50%
# 2011-02-01 - Last Month Result: 0.85%
# 2011-03-01 - Last Month Result: 0.28%
# 2011-04-01 - Last Month Result: 1.29%
# 2011-05-02 - Last Month Result: 0.70%
# 2011-06-01 - Last Month Result: -0.99%
# 2011-07-01 - Last Month Result: 0.50%
# 2011-08-01 - Last Month Result: -0.23%
# 2011-09-01 - Last Month Result: 0.28%
# 2011-10-03 - Last Month Result: -0.35%
# 2011-11-01 - Last Month Result: 0.02%
# 2011-12-01 - Last Month Result: 0.00%
# 2012-01-03 - Last Month Result: 0.00%
# 2012-02-01 - Last Month Result: 0.10%
# 2012-03-01 - Last Month Result: 0.53%
# 2012-04-02 - Last Month Result: 0.62%
# 2012-05-01 - Last Month Result: -0.12%
# 2012-06-01 - Last Month Result: -3.90%
# 2012-07-02 - Last Month Result: 1.19%
# 2012-08-01 - Last Month Result: 0.15%
# 2012-09-04 - Last Month Result: -0.17%
# 2012-10-01 - Last Month Result: 0.15%
# 2012-11-01 - Last Month Result: -0.05%
# 2012-12-03 - Last Month Result: -0.20%
# 2013-01-02 - Last Month Result: 0.77%
# 2013-02-01 - Last Month Result: 0.61%
# 2013-03-01 - Last Month Result: 0.07%
# 2013-04-01 - Last Month Result: 0.32%
# 2013-05-01 - Last Month Result: -0.20%
# 2013-06-03 - Last Month Result: 1.41%
# 2013-07-01 - Last Month Result: -0.05%
# 2013-08-01 - Last Month Result: 1.20%
# 2013-09-03 - Last Month Result: -1.55%
# 2013-10-01 - Last Month Result: 0.22%
# 2013-11-01 - Last Month Result: 0.19%
# 2013-12-02 - Last Month Result: -0.03%
# 2014-01-02 - Last Month Result: 0.17%
# 2014-02-03 - Last Month Result: -0.87%
# 2014-03-03 - Last Month Result: 0.34%
# 2014-04-01 - Last Month Result: -0.25%
# 2014-05-01 - Last Month Result: 0.08%
# 2014-06-02 - Last Month Result: 0.06%
# 2014-07-01 - Last Month Result: 0.16%
# 2014-08-01 - Last Month Result: -0.23%
# 2014-09-02 - Last Month Result: 0.26%
# 2014-10-01 - Last Month Result: -0.13%
# 2014-11-03 - Last Month Result: 0.42%
# 2014-12-01 - Last Month Result: 0.14%
# 2015-01-02 - Last Month Result: 0.02%
# 2015-02-02 - Last Month Result: 0.00%
# 2015-03-02 - Last Month Result: 0.00%
# 2015-04-01 - Last Month Result: 0.00%
# 2015-05-01 - Last Month Result: 0.00%
# 2015-06-01 - Last Month Result: 0.00%
# 2015-07-01 - Last Month Result: 0.00%
# 2015-08-03 - Last Month Result: 0.00%
# 2015-09-01 - Last Month Result: 0.00%
# 2015-10-01 - Last Month Result: 0.00%
# 2015-11-02 - Last Month Result: 0.00%
# 2015-12-01 - Last Month Result: 0.06%
# 2016-01-04 - Last Month Result: -0.18%
# 2016-02-01 - Last Month Result: 0.03%
# 2016-03-01 - Last Month Result: 0.00%
# 2016-04-01 - Last Month Result: 0.30%
# 2016-05-02 - Last Month Result: -0.29%
# 2016-06-01 - Last Month Result: 0.09%
# 2016-07-01 - Last Month Result: 0.04%
# 2016-08-01 - Last Month Result: 0.25%
# 2016-09-01 - Last Month Result: -0.41%
# 2016-10-03 - Last Month Result: 0.01%
# 2016-11-01 - Last Month Result: -0.22%
# 2016-12-01 - Last Month Result: -0.06%
# 2017-01-03 - Last Month Result: 0.31%
# 2017-02-01 - Last Month Result: -0.02%
# 2017-03-01 - Last Month Result: 1.11%
# 2017-04-03 - Last Month Result: -0.69%
# 2017-05-01 - Last Month Result: 0.11%
# 2017-06-01 - Last Month Result: 0.12%
# 2017-07-03 - Last Month Result: 0.32%
# 2017-08-01 - Last Month Result: 1.16%
# 2017-09-01 - Last Month Result: 0.03%
# 2017-10-02 - Last Month Result: 0.44%
# 2017-11-01 - Last Month Result: 0.76%
# Annualized Return: 1.13% Max Drawdown: -8.79%
# CPU times: user 1min 19s, sys: 5.74 s, total: 1min 24s
# Wall time: 1min 23s

# %%
returns, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(perf)
pf.create_returns_tear_sheet(returns, benchmark_rets=None)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>1997-01-02</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2017-11-30</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>250</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>1.1%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>26.4%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>3.7%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.32</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.13</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.88</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-8.8%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.08</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.45</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.80</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>20.33</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.05</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-0.5%</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:58: FutureWarning: 'argmin' is deprecated. Use 'idxmin' instead. The behavior of 'argmin' will be corrected to return the positional minimum in the future. Use 'series.values.argmin' to get the position of the minimum now.
#   return bound(*args, **kwds)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>8.79</td>
#       <td>1998-07-17</td>
#       <td>1998-08-31</td>
#       <td>2000-01-18</td>
#       <td>393</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>6.92</td>
#       <td>2000-03-24</td>
#       <td>2002-07-23</td>
#       <td>2005-02-01</td>
#       <td>1268</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5.72</td>
#       <td>1997-07-28</td>
#       <td>1997-10-27</td>
#       <td>1998-06-29</td>
#       <td>241</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5.08</td>
#       <td>1997-02-13</td>
#       <td>1997-04-11</td>
#       <td>1997-06-06</td>
#       <td>82</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4.88</td>
#       <td>2007-02-21</td>
#       <td>2008-01-30</td>
#       <td>2010-12-16</td>
#       <td>997</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_compat.py:57: MatplotlibDeprecationWarning:
# The compare_versions function was deprecated in Matplotlib 3.2 and will be removed two minor releases later.
#   return matplotlib.compare_versions('2.0.0', matplotlib.__version__)
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_compat.py:57: MatplotlibDeprecationWarning:
# The compare_versions function was deprecated in Matplotlib 3.2 and will be removed two minor releases later.
#   return matplotlib.compare_versions('2.0.0', matplotlib.__version__)
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_compat.py:57: MatplotlibDeprecationWarning:
# The compare_versions function was deprecated in Matplotlib 3.2 and will be removed two minor releases later.
#   return matplotlib.compare_versions('2.0.0', matplotlib.__version__)
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_compat.py:57: MatplotlibDeprecationWarning:
# The compare_versions function was deprecated in Matplotlib 3.2 and will be removed two minor releases later.
#   return matplotlib.compare_versions('2.0.0', matplotlib.__version__)
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_compat.py:57: MatplotlibDeprecationWarning:
# The compare_versions function was deprecated in Matplotlib 3.2 and will be removed two minor releases later.
#   return matplotlib.compare_versions('2.0.0', matplotlib.__version__)
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_compat.py:57: MatplotlibDeprecationWarning:
# The compare_versions function was deprecated in Matplotlib 3.2 and will be removed two minor releases later.
#   return matplotlib.compare_versions('2.0.0', matplotlib.__version__)
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /usr/local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:58: FutureWarning: 'argmin' is deprecated. Use 'idxmin' instead. The behavior of 'argmin' will be corrected to return the positional minimum in the future. Use 'series.values.argmin' to get the position of the minimum now.
#   return bound(*args, **kwds)
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_compat.py:57: MatplotlibDeprecationWarning:
# The compare_versions function was deprecated in Matplotlib 3.2 and will be removed two minor releases later.
#   return matplotlib.compare_versions('2.0.0', matplotlib.__version__)
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_compat.py:57: MatplotlibDeprecationWarning:
# The compare_versions function was deprecated in Matplotlib 3.2 and will be removed two minor releases later.
#   return matplotlib.compare_versions('2.0.0', matplotlib.__version__)
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
